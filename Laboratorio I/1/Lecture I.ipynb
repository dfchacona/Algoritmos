# %%
2 + 2
# Out:
# 4

# %%
x=2

# %%
2+2
3+3
# Out:
# 6

# %%
print (2+2)
3+3
# Out:
# 4
# 6

# %%
#Take some time to run something
c = 0
for i in range(10000000):
    c = c + i
c
# Out:
# 49999995000000

# %%
import numpy as np
import pandas as pd

# This is a plotting library for pretty pictures.
import matplotlib.pyplot as plt

# %%
# Sample 100 points with a mean of 0 and an std of 1. This is a standard normal distribution.
X = np.random.normal(0, 1, 100)

# %% [markdown]
# ## Plotting

# %%
plt.plot(X)

# %% [markdown]
# ### Eje x

# %%
X = np.random.normal(0, 1, 100)
X2 = np.random.normal(0, 1, 100)
print (type (X))
plt.plot(X);
plt.plot(X2);
plt.xlabel('Time') # The data we generated is unitless, but don't forget units in general.
plt.ylabel('Returns')
plt.legend(['X', 'X2']);
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# ### Estadisticas

# %%
np.mean(X)
# Out:
# 0.03635506774606032

# %%
np.std(X)
# Out:
# 0.9482739077177937

# %%
data = get_pricing.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-2a6f498dd3b0> in <module>()
# ----> 1 data = get_pricing('MSFT', start_date='2012-1-1', end_date='2015-6-1')
#
# NameError: name 'get_pricing' is not defined

# %%
MAVG = pd.rolling_mean(X, window=60)
plt.plot(X.index, X.values)
plt.plot(MAVG.index, MAVG.values)
plt.ylabel('Price')
plt.legend(['MSFT', '60-day MAVG']);
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: pd.rolling_mean is deprecated for ndarrays and will be removed in a future version
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-98b16a1fa5a4> in <module>()
#       1 MAVG = pd.rolling_mean(X, window=60)
# ----> 2 plt.plot(X.index, X.values)
#       3 plt.plot(MAVG.index, MAVG.values)
#       4 plt.ylabel('Price')
#       5 plt.legend(['MSFT', '60-day MAVG']);
#
# AttributeError: 'numpy.ndarray' object has no attribute 'index'

# %%
import matplotlib.pyplot as plt
import numpy as np
from time import time
a=0
b=1

list= []

for j in range(2, 2000):
    n=j
    start_time = time()
    for i in range(2,n):

        ans=a+b
        a=b
        b=ans
        
    elapsed_time = time() - start_time
    list.append(elapsed_time)
returns =np.array(list)
plt.ylabel('Time (s)') # The data we generated is unitless, but don't forget units in general.
plt.xlabel('Term #(n)')
plt.plot(returns)

# %%
import matplotlib.pyplot as plt
import numpy as np
from time import time

listA=[]
for j in range(2, 10):
    A = np.zeros((j, j))
    A += np.random.normal(20, 0.02)
    B = np.zeros((j, j))
    B += np.random.normal(10, 0.03)
    start_time = time()
    ans= A*B

    
    elapsed_time = time() - start_time
    listA.append(elapsed_time)
returns =np.array(listA)
plt.plot(returns)
