# %%
import matplotlib.pyplot as plt
import numpy as np
from time import time


returns =np.array([1010245, 1116195, 1130473, 213597, 238469, 185789, 185390, 252450, 186433, 187244, 186026, 186948, 188426, 188430, 185776, 185702, 186022, 185119, 185640, 185749, 186077, 186352, 185516, 185486, 185900, 185159, 186286, 185175, 186118, 185226 ] 
)
print (returns)
plt.plot(returns)
# Out:
# [1010245 1116195 1130473  213597  238469  185789  185390  252450  186433
#   187244  186026  186948  188426  188430  185776  185702  186022  185119
#   185640  185749  186077  186352  185516  185486  185900  185159  186286
#   185175  186118  185226]

# %%
import matplotlib.pyplot as plt
import numpy as np
from time import time


returns =np.array([890319, 875585, 1007589, 12423209, 27992, 27655, 27602, 27634, 27628, 27607, 31898, 27645, 27625, 27624, 27621, 27705, 27648, 27586, 27617, 27639, 27636, 27594, 27654, 27615, 27624, 27641, 29083, 27624, 27618, 27623 ] )
print (returns)
plt.plot(returns)
# Out:
# [  890319   875585  1007589 12423209    27992    27655    27602    27634
#     27628    27607    31898    27645    27625    27624    27621    27705
#     27648    27586    27617    27639    27636    27594    27654    27615
#     27624    27641    29083    27624    27618    27623]
