# %%
import matplotlib.pyplot as plt
import numpy as np
from time import time


returns =np.array([48764, 44624, 44795, 44410, 44594, 44570, 44539, 44087, 51676, 40862, 41729, 41522, 50986, 48571, 45159, 44688, 44227, 44266, 44047, 340179, 47157, 45309, 44112, 44548, 44414, 47412, 44433, 44040, 421834, 44444 ] 
)
print (returns)
plt.plot(returns)
# Out:
# [ 48764  44624  44795  44410  44594  44570  44539  44087  51676  40862
#   41729  41522  50986  48571  45159  44688  44227  44266  44047 340179
#   47157  45309  44112  44548  44414  47412  44433  44040 421834  44444]

# %%
import matplotlib.pyplot as plt
import numpy as np
from time import time


returns =np.array([42293, 39798, 38184, 45213, 38100, 38083, 38121, 38009, 38130, 38042, 38064, 38468, 42753, 38735, 38146, 38182, 38113, 38171, 38022, 38255, 37978, 38104, 38007, 38576, 38021, 37957, 39902, 38078, 38217, 38056 ] )
print (returns)
plt.plot(returns)
# Out:
# [42293 39798 38184 45213 38100 38083 38121 38009 38130 38042 38064 38468
#  42753 38735 38146 38182 38113 38171 38022 38255 37978 38104 38007 38576
#  38021 37957 39902 38078 38217 38056]
